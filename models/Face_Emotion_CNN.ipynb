# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os
from keras.preprocessing.image import ImageDataGenerator, load_img
from keras.layers import Conv2D, Dense, BatchNormalization, Activation, Dropout, MaxPooling2D, Flatten
from tensorflow.keras.optimizers import Adam, RMSprop, SGD
from keras.callbacks import ModelCheckpoint,EarlyStopping
import datetime
from keras import regularizers
import matplotlib.pyplot as plt
#from keras.utils.vis_utils import plot_model

# %%
#Mounting Google Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from zipfile import ZipFile
zf = ZipFile("/content/xyz.zip")
zf.extractall('/content')
zf.close()

# %%
train_dir = '/content/images/train/'
test_dir = '/content/images/validation/'

row, col = 48, 48
classes = 7

def count_exp(path, set_):
    dict_ = {}
    for expression in os.listdir(path):
        dir_ = path + expression
        dict_[expression] = len(os.listdir(dir_))
    df = pd.DataFrame(dict_, index=[set_])
    return df
train_count = count_exp(train_dir, 'train')
test_count = count_exp(test_dir, 'test')
print(train_count)
print(test_count)

# %%
train_count.transpose().plot(kind='bar')
test_count.transpose().plot(kind='bar')
# Out:
# <Axes: >

# %%
i = 1
for expression in os.listdir(train_dir):
    img = load_img((train_dir + expression +'/'+ os.listdir(train_dir + expression)[5]))
    plt.subplot(1,7,i)
    plt.imshow(img)
    plt.title(expression)
    plt.axis('off')
    i += 1
plt.show()

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True,
                                   validation_split=0.2)

training_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical',
                                                subset='training')
validation_set = train_datagen.flow_from_directory(train_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical',
                                                subset='validation')

test_datagen = ImageDataGenerator(rescale=1./255,
                                   horizontal_flip=True)
test_set = test_datagen.flow_from_directory(test_dir,
                                                batch_size=64,
                                                target_size=(48,48),
                                                shuffle=True,
                                                color_mode='grayscale',
                                                class_mode='categorical')
# Out:
# Found 23060 images belonging to 7 classes.
# Found 5761 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %%
training_set.class_indices
# Out:
# {'angry': 0,
#  'disgust': 1,
#  'fear': 2,
#  'happy': 3,
#  'neutral': 4,
#  'sad': 5,
#  'surprise': 6}

# %%
class_labels = {'angry': 0,
 'disgust': 1,
 'fear': 2,
 'happy': 3,
 'neutral': 4,
 'sad': 5,
 'surprise': 6}

# %%
weight_decay = 1e-4

num_classes = 7

model = tf.keras.models.Sequential()

model.add(Conv2D(64, (4,4), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=(48,48,1)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (4,4), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Conv2D(128, (4,4), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

model.add(Conv2D(128, (4,4), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (4,4), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('elu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128, activation="linear"))
model.add(Activation('elu'))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer=Adam(0.0003), metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 64)        1088
#
#  activation (Activation)     (None, 48, 48, 64)        0
#
#  batch_normalization (Batch  (None, 48, 48, 64)        256
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        65600
#
#  activation_1 (Activation)   (None, 48, 48, 64)        0
#
#  batch_normalization_1 (Bat  (None, 48, 48, 64)        256
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       131200
#
#  activation_2 (Activation)   (None, 24, 24, 128)       0
#
#  batch_normalization_2 (Bat  (None, 24, 24, 128)       512
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 128)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 128)       262272
#
#  activation_3 (Activation)   (None, 12, 12, 128)       0
#
#  batch_normalization_3 (Bat  (None, 12, 12, 128)       512
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 128)       262272
#
#  activation_4 (Activation)   (None, 12, 12, 128)       0
#
#  batch_normalization_4 (Bat  (None, 12, 12, 128)       512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 128)               589952
#
#  activation_5 (Activation)   (None, 128)               0
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 1315335 (5.02 MB)
# Trainable params: 1314311 (5.01 MB)
# Non-trainable params: 1024 (4.00 KB)
# _________________________________________________________________

# %%
# !pip install keras-utils
# Out:
# Collecting keras-utils
#   Downloading keras-utils-1.0.13.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from keras-utils) (2.14.0)
# Building wheels for collected packages: keras-utils
#   Building wheel for keras-utils (setup.py) ... done
#   Created wheel for keras-utils: filename=keras_utils-1.0.13-py3-none-any.whl size=2631 sha256=dce8e7abfe1fe9bb95e75cf3d1f2588aa2bfa29565bdd3d7d52526ee9755cae0
#   Stored in directory: /root/.cache/pip/wheels/5c/c0/b3/0c332de4fd71f3733ea6d61697464b7ae4b2b5ff0300e6ca7a
# Successfully built keras-utils
# Installing collected packages: keras-utils
# Successfully installed keras-utils-1.0.13

# %%
checkpointer = [EarlyStopping(monitor = 'val_accuracy', verbose = 1, restore_best_weights=True,mode="max",patience = 10),
                ModelCheckpoint(
                    filepath='model.weights.best.hdf5',
                    monitor="val_accuracy",
                    verbose=1,
                    save_best_only=True,
                    mode="max")]

# %%
steps_per_epoch = training_set.n // training_set.batch_size
validation_steps = validation_set.n // validation_set.batch_size

history = model.fit(x=training_set,
                 validation_data=validation_set,
                 epochs=31,
                 callbacks=[checkpointer],
                 steps_per_epoch=steps_per_epoch,
                 validation_steps=validation_steps)
# Out:
# Epoch 1/31
# 360/360 [==============================] - ETA: 0s - loss: 1.8067 - accuracy: 0.3243
# Epoch 1: val_accuracy improved from -inf to 0.32413, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 49s 78ms/step - loss: 1.8067 - accuracy: 0.3243 - val_loss: 1.8036 - val_accuracy: 0.3241
# Epoch 2/31
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 359/360 [============================>.] - ETA: 0s - loss: 1.5526 - accuracy: 0.4154
# Epoch 2: val_accuracy improved from 0.32413 to 0.45052, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 21s 57ms/step - loss: 1.5520 - accuracy: 0.4158 - val_loss: 1.4811 - val_accuracy: 0.4505
# Epoch 3/31
# 359/360 [============================>.] - ETA: 0s - loss: 1.4495 - accuracy: 0.4565
# Epoch 3: val_accuracy improved from 0.45052 to 0.47795, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 22s 60ms/step - loss: 1.4491 - accuracy: 0.4567 - val_loss: 1.3796 - val_accuracy: 0.4780
# Epoch 4/31
# 360/360 [==============================] - ETA: 0s - loss: 1.3650 - accuracy: 0.4919
# Epoch 4: val_accuracy improved from 0.47795 to 0.49774, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 22s 61ms/step - loss: 1.3650 - accuracy: 0.4919 - val_loss: 1.3318 - val_accuracy: 0.4977
# Epoch 5/31
# 359/360 [============================>.] - ETA: 0s - loss: 1.2981 - accuracy: 0.5209
# Epoch 5: val_accuracy improved from 0.49774 to 0.51580, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 22s 62ms/step - loss: 1.2981 - accuracy: 0.5208 - val_loss: 1.3133 - val_accuracy: 0.5158
# Epoch 6/31
# 360/360 [==============================] - ETA: 0s - loss: 1.2514 - accuracy: 0.5411
# Epoch 6: val_accuracy improved from 0.51580 to 0.53576, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 21s 58ms/step - loss: 1.2514 - accuracy: 0.5411 - val_loss: 1.2596 - val_accuracy: 0.5358
# Epoch 7/31
# 360/360 [==============================] - ETA: 0s - loss: 1.2032 - accuracy: 0.5581
# Epoch 7: val_accuracy improved from 0.53576 to 0.55243, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 21s 59ms/step - loss: 1.2032 - accuracy: 0.5581 - val_loss: 1.2218 - val_accuracy: 0.5524
# Epoch 8/31
# 360/360 [==============================] - ETA: 0s - loss: 1.1617 - accuracy: 0.5770
# Epoch 8: val_accuracy improved from 0.55243 to 0.57517, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 24s 67ms/step - loss: 1.1617 - accuracy: 0.5770 - val_loss: 1.1771 - val_accuracy: 0.5752
# Epoch 9/31
# 359/360 [============================>.] - ETA: 0s - loss: 1.1262 - accuracy: 0.5901
# Epoch 9: val_accuracy did not improve from 0.57517
# 360/360 [==============================] - 21s 59ms/step - loss: 1.1262 - accuracy: 0.5901 - val_loss: 1.2022 - val_accuracy: 0.5620
# Epoch 10/31
# 360/360 [==============================] - ETA: 0s - loss: 1.0927 - accuracy: 0.6079
# Epoch 10: val_accuracy improved from 0.57517 to 0.57969, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 22s 60ms/step - loss: 1.0927 - accuracy: 0.6079 - val_loss: 1.1765 - val_accuracy: 0.5797
# Epoch 11/31
# 360/360 [==============================] - ETA: 0s - loss: 1.0618 - accuracy: 0.6147
# Epoch 11: val_accuracy improved from 0.57969 to 0.58229, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 22s 60ms/step - loss: 1.0618 - accuracy: 0.6147 - val_loss: 1.1763 - val_accuracy: 0.5823
# Epoch 12/31
# 359/360 [============================>.] - ETA: 0s - loss: 1.0261 - accuracy: 0.6303
# Epoch 12: val_accuracy did not improve from 0.58229
# 360/360 [==============================] - 21s 57ms/step - loss: 1.0261 - accuracy: 0.6301 - val_loss: 1.1675 - val_accuracy: 0.5821
# Epoch 13/31
# 359/360 [============================>.] - ETA: 0s - loss: 1.0007 - accuracy: 0.6429
# Epoch 13: val_accuracy improved from 0.58229 to 0.59688, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 21s 58ms/step - loss: 1.0011 - accuracy: 0.6427 - val_loss: 1.1420 - val_accuracy: 0.5969
# Epoch 14/31
# 359/360 [============================>.] - ETA: 0s - loss: 0.9689 - accuracy: 0.6542
# Epoch 14: val_accuracy improved from 0.59688 to 0.59878, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 24s 67ms/step - loss: 0.9689 - accuracy: 0.6541 - val_loss: 1.1496 - val_accuracy: 0.5988
# Epoch 15/31
# 360/360 [==============================] - ETA: 0s - loss: 0.9456 - accuracy: 0.6649
# Epoch 15: val_accuracy did not improve from 0.59878
# 360/360 [==============================] - 21s 59ms/step - loss: 0.9456 - accuracy: 0.6649 - val_loss: 1.1810 - val_accuracy: 0.5946
# Epoch 16/31
# 360/360 [==============================] - ETA: 0s - loss: 0.9162 - accuracy: 0.6792
# Epoch 16: val_accuracy improved from 0.59878 to 0.61372, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 21s 59ms/step - loss: 0.9162 - accuracy: 0.6792 - val_loss: 1.1455 - val_accuracy: 0.6137
# Epoch 17/31
# 360/360 [==============================] - ETA: 0s - loss: 0.8818 - accuracy: 0.6929
# Epoch 17: val_accuracy did not improve from 0.61372
# 360/360 [==============================] - 21s 58ms/step - loss: 0.8818 - accuracy: 0.6929 - val_loss: 1.1673 - val_accuracy: 0.6010
# Epoch 18/31
# 360/360 [==============================] - ETA: 0s - loss: 0.8556 - accuracy: 0.7044
# Epoch 18: val_accuracy did not improve from 0.61372
# 360/360 [==============================] - 21s 60ms/step - loss: 0.8556 - accuracy: 0.7044 - val_loss: 1.1542 - val_accuracy: 0.6089
# Epoch 19/31
# 360/360 [==============================] - ETA: 0s - loss: 0.8339 - accuracy: 0.7122
# Epoch 19: val_accuracy did not improve from 0.61372
# 360/360 [==============================] - 22s 60ms/step - loss: 0.8339 - accuracy: 0.7122 - val_loss: 1.1777 - val_accuracy: 0.6115
# Epoch 20/31
# 360/360 [==============================] - ETA: 0s - loss: 0.8020 - accuracy: 0.7232
# Epoch 20: val_accuracy did not improve from 0.61372
# 360/360 [==============================] - 21s 57ms/step - loss: 0.8020 - accuracy: 0.7232 - val_loss: 1.1536 - val_accuracy: 0.6061
# Epoch 21/31
# 359/360 [============================>.] - ETA: 0s - loss: 0.7807 - accuracy: 0.7308
# Epoch 21: val_accuracy did not improve from 0.61372
# 360/360 [==============================] - 21s 58ms/step - loss: 0.7803 - accuracy: 0.7310 - val_loss: 1.2017 - val_accuracy: 0.6023
# Epoch 22/31
# 360/360 [==============================] - ETA: 0s - loss: 0.7642 - accuracy: 0.7429
# Epoch 22: val_accuracy did not improve from 0.61372
# 360/360 [==============================] - 21s 59ms/step - loss: 0.7642 - accuracy: 0.7429 - val_loss: 1.2618 - val_accuracy: 0.5995
# Epoch 23/31
# 360/360 [==============================] - ETA: 0s - loss: 0.7283 - accuracy: 0.7578
# Epoch 23: val_accuracy improved from 0.61372 to 0.62413, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 22s 60ms/step - loss: 0.7283 - accuracy: 0.7578 - val_loss: 1.2105 - val_accuracy: 0.6241
# Epoch 24/31
# 360/360 [==============================] - ETA: 0s - loss: 0.7010 - accuracy: 0.7701
# Epoch 24: val_accuracy did not improve from 0.62413
# 360/360 [==============================] - 21s 59ms/step - loss: 0.7010 - accuracy: 0.7701 - val_loss: 1.2253 - val_accuracy: 0.6219
# Epoch 25/31
# 360/360 [==============================] - ETA: 0s - loss: 0.6791 - accuracy: 0.7785
# Epoch 25: val_accuracy did not improve from 0.62413
# 360/360 [==============================] - 21s 59ms/step - loss: 0.6791 - accuracy: 0.7785 - val_loss: 1.2709 - val_accuracy: 0.6210
# Epoch 26/31
# 359/360 [============================>.] - ETA: 0s - loss: 0.6564 - accuracy: 0.7875
# Epoch 26: val_accuracy did not improve from 0.62413
# 360/360 [==============================] - 21s 58ms/step - loss: 0.6565 - accuracy: 0.7874 - val_loss: 1.2686 - val_accuracy: 0.6161
# Epoch 27/31
# 360/360 [==============================] - ETA: 0s - loss: 0.6341 - accuracy: 0.7957
# Epoch 27: val_accuracy did not improve from 0.62413
# 360/360 [==============================] - 21s 58ms/step - loss: 0.6341 - accuracy: 0.7957 - val_loss: 1.3154 - val_accuracy: 0.6141
# Epoch 28/31
# 360/360 [==============================] - ETA: 0s - loss: 0.6227 - accuracy: 0.8003
# Epoch 28: val_accuracy did not improve from 0.62413
# 360/360 [==============================] - 21s 59ms/step - loss: 0.6227 - accuracy: 0.8003 - val_loss: 1.3194 - val_accuracy: 0.6094
# Epoch 29/31
# 360/360 [==============================] - ETA: 0s - loss: 0.5969 - accuracy: 0.8118
# Epoch 29: val_accuracy did not improve from 0.62413
# 360/360 [==============================] - 24s 66ms/step - loss: 0.5969 - accuracy: 0.8118 - val_loss: 1.3398 - val_accuracy: 0.6141
# Epoch 30/31
# 360/360 [==============================] - ETA: 0s - loss: 0.5913 - accuracy: 0.8142
# Epoch 30: val_accuracy did not improve from 0.62413
# 360/360 [==============================] - 21s 58ms/step - loss: 0.5913 - accuracy: 0.8142 - val_loss: 1.3368 - val_accuracy: 0.6191
# Epoch 31/31
# 359/360 [============================>.] - ETA: 0s - loss: 0.5626 - accuracy: 0.8257
# Epoch 31: val_accuracy improved from 0.62413 to 0.62500, saving model to model.weights.best.hdf5
# 360/360 [==============================] - 24s 67ms/step - loss: 0.5631 - accuracy: 0.8256 - val_loss: 1.3580 - val_accuracy: 0.6250

# %%
training_loss = history.history['loss']
val_loss = history.history['val_loss']
plt.rcParams['figure.figsize'] = [10, 5]
plt.style.use(['default'])
# Create count of the number of epochs
epoch_count = range(1, len(training_loss) + 1)

# Visualize loss history
plt.plot(epoch_count, training_loss, 'r--')
plt.plot(epoch_count, val_loss, 'b-')
plt.legend(['Training Loss', 'Val Loss'])
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.show()

# %%
training_accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']

# Create count of the number of epochs
epoch_count = range(1, len(training_accuracy) + 1)

# Visualize loss history

plt.plot(epoch_count, training_accuracy, 'r--')
plt.plot(epoch_count, val_accuracy, 'b-')
plt.legend(['Training Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim(top = 1)
plt.show()

# %%
# saving the model
model.save("fer_model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
print(f"Test accuracy = {model.evaluate(test_set ,batch_size=test_set.batch_size,steps=test_set.n // test_set.batch_size)[1]*100}%")
# Out:
# 110/110 [==============================] - 3s 29ms/step - loss: 1.3232 - accuracy: 0.6270
# Test accuracy = 62.69886493682861%

# %%
x_test,y_test = next(test_set)
predict = model.predict(x_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step
